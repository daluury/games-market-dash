# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv('C:/Users/Darya/Desktop/games.csv')
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#        Critic_Score User_Score Rating
# ...

# %%
data = pd.read_csv('C:/Users/Darya/Desktop/games.csv')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=16719, step=1)

# %%
data.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Critic_Score',
#        'User_Score', 'Rating'],
#       dtype='object')

# %%
data.dropna() # удалили все записи с NaN
# Out:
#                           Name Platform  Year_of_Release     Genre  \
# 0                   Wii Sports      Wii           2006.0    Sports
# 2               Mario Kart Wii      Wii           2008.0    Racing
# 3            Wii Sports Resort      Wii           2009.0    Sports
# 6        New Super Mario Bros.       DS           2006.0  Platform
# 7                     Wii Play      Wii           2006.0      Misc
# ...                        ...      ...              ...       ...
# 16699          Planet Monsters      GBA           2001.0    Action
# 16700                   Breach       PC           2011.0   Shooter
# 16701         Bust-A-Move 3000       GC           2003.0    Puzzle
# 16702         Mega Brain Boost       DS           2008.0    Puzzle
# 16706  STORM: Frontline Nation       PC           2011.0  Strategy
#
#        Critic_Score User_Score Rating
# 0              76.0          8      E
# 2              82.0        8.3      E
# 3              80.0          8      E
# ...

# %%
data = data.dropna() # сохраняем результат

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7878 entries, 0 to 16706
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             7878 non-null   object
#  1   Platform         7878 non-null   object
#  2   Year_of_Release  7878 non-null   float64
#  3   Genre            7878 non-null   object
#  4   Critic_Score     7878 non-null   float64
#  5   User_Score       7878 non-null   object
#  6   Rating           7878 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 492.4+ KB

# %%
data.sample(5)
# Out:
#                              Name Platform  Year_of_Release         Genre  \
# 864    Spyro: Enter the Dragonfly      PS2           2002.0      Platform
# 1877                      NFL 2K1       DC           2000.0        Sports
# 8862       Space Invaders Extreme       DS           2008.0       Shooter
# 14214         Planescape: Torment       PC           1998.0  Role-Playing
# 3094                    F-Zero GX       GC           2003.0        Racing
#
#        Critic_Score User_Score Rating
# 864            56.0        4.1      E
# 1877           97.0          6      E
# 8862           85.0        7.6      E
# 14214          91.0        9.2      T
# 3094           89.0        8.5      T

# %%
data.loc[data['User_Score'] != 'tbd']
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 0                             Wii Sports      Wii           2006.0    Sports
# 2                         Mario Kart Wii      Wii           2008.0    Racing
# 3                      Wii Sports Resort      Wii           2009.0    Sports
# 6                  New Super Mario Bros.       DS           2006.0  Platform
# 7                               Wii Play      Wii           2006.0      Misc
# ...                                  ...      ...              ...       ...
# 16667         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 16700                             Breach       PC           2011.0   Shooter
# 16706            STORM: Frontline Nation       PC           2011.0  Strategy
#
#        Critic_Score User_Score Rating
# ...

# %%
data = data.loc[data['User_Score'] != 'tbd'] # сохраняем результат удаления tbd

# %%
data.index
# Out:
# Int64Index([    0,     2,     3,     6,     7,     8,    11,    13,    14,
#                15,
#             ...
#             16624, 16631, 16634, 16644, 16656, 16667, 16677, 16696, 16700,
#             16706],
#            dtype='int64', length=6826)

# %%
data.sample(10)
# Out:
#                                                     Name Platform  \
# 4911   Final Fantasy Crystal Chronicles: The Crystal ...      Wii
# 3845                               Rory McIlroy PGA Tour      PS4
# 14692  Buffy the Vampire Slayer: Wrath of the Darkhul...      GBA
# 7873                          50 Cent: Blood on the Sand      PS3
# 3832                                         NBA Live 08     X360
# 15444                             Headhunter: Redemption       XB
# 8753                          Kingdom Under Fire: Heroes       XB
# 16553                                    Sega Rally Revo       PC
# 14127                              Painkiller: Hell Wars       XB
# 2407                                     Warriors Orochi      PS2
#
#        Year_of_Release     Genre  Critic_Score User_Score Rating
# 4911            2009.0    Action          66.0        7.6      T
# 3845            2015.0    Action          61.0        3.7      E
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6826 entries, 0 to 16706
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6826 non-null   object
#  1   Platform         6826 non-null   object
#  2   Year_of_Release  6826 non-null   float64
#  3   Genre            6826 non-null   object
#  4   Critic_Score     6826 non-null   float64
#  5   User_Score       6826 non-null   object
#  6   Rating           6826 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 426.6+ KB

# %%
data['Year_of_Release']
# Out:
# 0        2006.0
# 2        2008.0
# 3        2009.0
# 6        2006.0
# 7        2006.0
#           ...
# 16667    2001.0
# 16677    2002.0
# 16696    2014.0
# 16700    2011.0
# 16706    2011.0
# Name: Year_of_Release, Length: 6826, dtype: float64

# %%
data['Year_of_Release'] = data['Year_of_Release'].astype(int) # переводим год в тип int

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6826 entries, 0 to 16706
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6826 non-null   object
#  1   Platform         6826 non-null   object
#  2   Year_of_Release  6826 non-null   int32
#  3   Genre            6826 non-null   object
#  4   Critic_Score     6826 non-null   float64
#  5   User_Score       6826 non-null   object
#  6   Rating           6826 non-null   object
# dtypes: float64(1), int32(1), object(5)
# memory usage: 400.0+ KB

# %%
data.sample(10)
# Out:
#                                         Name Platform  Year_of_Release  \
# 5135                      Virtua Tennis 2009      Wii             2009
# 1213         Warcraft III: The Frozen Throne       PC             2003
# 2192   Tom Clancy's Splinter Cell: Blacklist      PS3             2013
# 5490                    Planet Puzzle League       DS             2007
# 1167               Pokemon Battle Revolution      Wii             2006
# 11578                  From Russia With Love      PSP             2006
# 2910                              SplashDown      PS2             2001
# 6411             Need for Speed: Most Wanted       DS             2005
# 14282                             EverBlue 2      PS2             2002
# 1721   Resident Evil: Operation Raccoon City      PS3             2012
#
#               Genre  Critic_Score User_Score Rating
# 5135         Sports          73.0        7.7      E
# 1213       Strategy          88.0          9      T
# ...

# %%
data.loc[data['Year_of_Release'] >= 2000] # отсеяли все ранее 2000
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 0                             Wii Sports      Wii             2006    Sports
# 2                         Mario Kart Wii      Wii             2008    Racing
# 3                      Wii Sports Resort      Wii             2009    Sports
# 6                  New Super Mario Bros.       DS             2006  Platform
# 7                               Wii Play      Wii             2006      Misc
# ...                                  ...      ...              ...       ...
# 16667         E.T. The Extra-Terrestrial      GBA             2001    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA             2002  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC             2014    Action
# 16700                             Breach       PC             2011   Shooter
# 16706            STORM: Frontline Nation       PC             2011  Strategy
#
#        Critic_Score User_Score Rating
# ...

# %%
data = data.loc[data['Year_of_Release'] >= 2000] # сохраняем результат

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6747 entries, 0 to 16706
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6747 non-null   object
#  1   Platform         6747 non-null   object
#  2   Year_of_Release  6747 non-null   int32
#  3   Genre            6747 non-null   object
#  4   Critic_Score     6747 non-null   float64
#  5   User_Score       6747 non-null   object
#  6   Rating           6747 non-null   object
# dtypes: float64(1), int32(1), object(5)
# memory usage: 395.3+ KB

# %%
data['User_Score'] = data['User_Score'].astype(float) # переводим оценку пользователей в флоат

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6747 entries, 0 to 16706
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6747 non-null   object
#  1   Platform         6747 non-null   object
#  2   Year_of_Release  6747 non-null   int32
#  3   Genre            6747 non-null   object
#  4   Critic_Score     6747 non-null   float64
#  5   User_Score       6747 non-null   float64
#  6   Rating           6747 non-null   object
# dtypes: float64(2), int32(1), object(4)
# memory usage: 395.3+ KB

# %%
data['Critic_Score'] = data['Critic_Score'].astype(int) # переводим оценку критиков в int

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6747 entries, 0 to 16706
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6747 non-null   object
#  1   Platform         6747 non-null   object
#  2   Year_of_Release  6747 non-null   int32
#  3   Genre            6747 non-null   object
#  4   Critic_Score     6747 non-null   int32
#  5   User_Score       6747 non-null   float64
#  6   Rating           6747 non-null   object
# dtypes: float64(1), int32(2), object(4)
# memory usage: 369.0+ KB

# %%
data.sample(30)
# Out:
#                                                     Name Platform  \
# 1872                                    NCAA Football 14     X360
# 2454                                   Tales of Xillia 2      PS3
# 4917                               Skylanders SWAP Force      PS4
# 1945                                       NBA Street V3      PS2
# 211                                            Fallout 3     X360
# 6858                            Bakugan: Battle Brawlers     X360
# 5572                                            Kinetica      PS2
# 2926               Mobile Suit Gundam: Journey to Jaburo      PS2
# 1584                      Star Wars: The Force Unleashed      PS2
# 5008                            Deus Ex: Mankind Divided      PS4
# 5869                  Romance of the Three Kingdoms VIII      PS2
# 9721        Makai Kingdom: Chronicles of the Sacred Tome      PS2
# 3963                                Test Drive Unlimited      PSP
# ...

# %%
data.to_csv('C:/Users/Darya/Desktop/Norm_games.csv', encoding='utf-8', index=False)

# %%
data.to_hdf('C:/Users/Darya/Desktop/Norm_games.h5', key='data', mode='a')

# %%
pd.read_hdf('C:/Users/Darya/Desktop/Norm_games.h5')
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 0                             Wii Sports      Wii             2006    Sports
# 2                         Mario Kart Wii      Wii             2008    Racing
# 3                      Wii Sports Resort      Wii             2009    Sports
# 6                  New Super Mario Bros.       DS             2006  Platform
# 7                               Wii Play      Wii             2006      Misc
# ...                                  ...      ...              ...       ...
# 16667         E.T. The Extra-Terrestrial      GBA             2001    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA             2002  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC             2014    Action
# 16700                             Breach       PC             2011   Shooter
# 16706            STORM: Frontline Nation       PC             2011  Strategy
#
#        Critic_Score  User_Score Rating
# ...

# %%
new_hdf = pd.read_hdf('C:/Users/Darya/Desktop/Norm_games.h5')

# %%
new_hdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6747 entries, 0 to 16706
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6747 non-null   object
#  1   Platform         6747 non-null   object
#  2   Year_of_Release  6747 non-null   int32
#  3   Genre            6747 non-null   object
#  4   Critic_Score     6747 non-null   int32
#  5   User_Score       6747 non-null   float64
#  6   Rating           6747 non-null   object
# dtypes: float64(1), int32(2), object(4)
# memory usage: 369.0+ KB

# %%
new_hdf.sample(30)
# Out:
#                                               Name Platform  Year_of_Release  \
# 11360                              Shining Soul II      GBA             2003
# 415        Professor Layton and the Unwound Future       DS             2008
# 12670  The History Channel: Battle for the Pacific     X360             2007
# 336                      Spyro: Year of the Dragon       PS             2000
# 356                                Luigi's Mansion       GC             2001
# 12846                                Mirror's Edge       PC             2009
# 11302                     BlazBlue Central Fiction      PS4             2016
# 636                          The Sims: Bustin' Out      PS2             2003
# 1995                      F-Zero: Maximum Velocity      GBA             2001
# 4883                                Project X Zone      3DS             2012
# 8463                                    Taz Wanted      PS2             2002
# ...

# %%
import numpy as np
new_csv = pd.read_csv('https://raw.githubusercontent.com/daluury/Games_market/main/Norm_games.csv', 
                      dtype = {'Year_of_Release': np.int32,
                               'Critic_Score': np.int32,
                               'User_Score': np.float64
                              }
                     )
new_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6747 entries, 0 to 6746
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6747 non-null   object
#  1   Platform         6747 non-null   object
#  2   Year_of_Release  6747 non-null   int32
#  3   Genre            6747 non-null   object
#  4   Critic_Score     6747 non-null   int32
#  5   User_Score       6747 non-null   float64
#  6   Rating           6747 non-null   object
# dtypes: float64(1), int32(2), object(4)
# memory usage: 316.4+ KB

# %%
new_csv.sample(30)
# Out:
#                                                 Name Platform  \
# 307               Dragon Ball Z: Budokai Tenkaichi 3      PS2
# 5771             Broken Sword 5: The Serpent's Curse      PS4
# 1797                                MLB 08: The Show      PS3
# 3006         Harry Potter and the Chamber of Secrets       XB
# 4181                                        Gungrave      PS2
# 186                                   Carnival Games      Wii
# 1136        Tom Clancy's Splinter Cell: Chaos Theory       XB
# 5853                                Song of the Deep     XOne
# 1234  Tom Clancy's Ghost Recon Advanced Warfighter 2      PS3
# 3145   Harry Potter and the Deathly Hallows - Part 2      Wii
# 1318                                    Dead Space 3      PS3
# 2305                                 Syphon Filter 3       PS
# 2534                               MX vs. ATV: Alive      PS3
# 4764                                   BIT.TRIP SAGA      3DS
# ...

# %%
max(new_csv['Year_of_Release'])
# Out:
# 2016

# %%
new_csv['Genre'].value_counts()
# Out:
# Action          1619
# Sports           941
# Shooter          859
# Role-Playing     691
# Racing           575
# Platform         397
# Misc             382
# Fighting         369
# Simulation       291
# Strategy         262
# Adventure        245
# Puzzle           116
# Name: Genre, dtype: int64

# %%
new_csv['Rating'].value_counts()
# Out:
# T       2338
# E       2058
# M       1420
# E10+     929
# RP         1
# AO         1
# Name: Rating, dtype: int64

# %%
new_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6747 entries, 0 to 6746
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6747 non-null   object
#  1   Platform         6747 non-null   object
#  2   Year_of_Release  6747 non-null   int32
#  3   Genre            6747 non-null   object
#  4   Critic_Score     6747 non-null   int32
#  5   User_Score       6747 non-null   float64
#  6   Rating           6747 non-null   object
# dtypes: float64(1), int32(2), object(4)
# memory usage: 316.4+ KB
